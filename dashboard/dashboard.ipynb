# %%
# %load_ext autoreload
# %autoreload 2

import dashboard as db
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
db.plot_dau_and_new_players()
# Out:
# [{'date': '2024-09-30', 'userCount': 1}]
# In: {'2024-09-30': 2}
# Out: [{'date': '2024-09-30', 'newPlayers': 2}]
# [{'date': '2024-09-30', 'newPlayers': 2}]

# %%
# db.plot_games_per_mode()

# %%
db.display_retention_table()
db.print_additional_info()
# Out:
#   Retention Period  Returning Players  Retention Rate (%)
# 0            Day 1                  0                   0
# 1            Day 7                  0                   0
# 2           Day 30                  0                   0
# 3        Yesterday                  0                   0
# Median Game Duration: 0.00 min
# Total Players: 2
# ATH of DAU: 1
# Yesterday's DAU: 0 (0.00% of ATH)

# %%
db.list_inactive_players()
# Out:
# No inactive players found.

# %%
db.get_player_log('rCF6z6SlxADfeZtWC0Z6D9WpFJWg')
# Out:
# 09-30 16:06:13 - fetchLeaderboard -
# {'tabId': 0}
#
# 09-30 16:06:30 - gameStart -
# {'gameId': '5b5cda1c-0d61-4d77-b824-3d35955bc6dd', 'league': None, 'mode': 0}
#
# 09-30 16:06:32 - leaveQueue -
# None
#
#
# Player Summary:
# Join Date: September 30, 2024 at 13:40:21
# Last Active Date: September 30, 2024 at 14:06:39
# Gold: 100000
# Rank: 1
# All Time Rank: 1
# Losses Streak: 0
#
# Characters:
#   Character ID: 9jGmiW6zminKmqK3Xw3o
#     Level: 1
#     XP: 0
#     SP: 0
#     All Time SP: 0
#     Skills: []
#     Inventory: []
#     Equipment: {'weapon': -1, 'armor': -1, 'helmet': -1, 'belt': -1, 'gloves': -1, 'boots': -1, 'left_ring': -1, 'right_ring': -1, 'necklace': -1}
#
#   Character ID: BTfnmGT6PGjOWl3Ae4mP
#     Level: 1
#     XP: 0
#     SP: 0
#     All Time SP: 0
#     Skills: [9]
#     Inventory: []
#     Equipment: {'weapon': -1, 'armor': -1, 'helmet': -1, 'belt': -1, 'gloves': -1, 'boots': -1, 'left_ring': -1, 'right_ring': -1, 'necklace': -1}
#
#   Character ID: 4pAz6xe2XuiapkidYGRm
#     Level: 1
#     XP: 0
#     SP: 0
#     All Time SP: 0
#     Skills: [0]
#     Inventory: []
#     Equipment: {'weapon': -1, 'armor': -1, 'helmet': -1, 'belt': -1, 'gloves': -1, 'boots': -1, 'left_ring': -1, 'right_ring': -1, 'necklace': -1}
#
#
# Utilization Stats: {'everPurchased': False, 'everSpentSP': False, 'everOpenedDailyLoot': False, 'everEquippedConsumable': False, 'everEquippedEquipment': False, 'everEquippedSpell': False, 'everUsedSpell': False, 'everPlayedPractice': False, 'everPlayedCasual': False, 'everPlayedRanked': False}
#
# Games Played:
# Game ID: 5b5cda1c-0d61-4d77-b824-3d35955bc6dd

# %%
# db.get_game_log('145c6a50-101d-48e0-a72a-209bcbde688b')
# Out:
# 09-30 09:49:05 - 2 -
# {'num': 1, 'tile': {'x': 13, 'y': 4}}
#
# 09-30 09:49:10 - 0 -
# {'index': 0, 'num': 3, 'target': 2, 'targetTeam': 2, 'x': 10, 'y': 5}
#
# 09-30 09:49:16 - 3 -
# {'num': 1, 'sameTeam': False, 'target': 1}
#
# 09-30 09:49:19 - 2 -
# {'num': 2, 'tile': {'x': 14, 'y': 3}}
#
# 09-30 09:49:25 - 3 -
# {'num': 2, 'sameTeam': False, 'target': 1}
#
# 09-30 09:49:27 - 2 -
# {'num': 1, 'tile': {'x': 13, 'y': 5}}
#
# 09-30 09:49:31 - 0 -
# {'index': 0, 'num': 3, 'target': 2, 'targetTeam': 2, 'x': 14, 'y': 5}
#
# 09-30 09:49:34 - 3 -
# {'num': 2, 'sameTeam': False, 'target': 2}
#
# 09-30 09:49:41 - 2 -
# {'num': 1, 'tile': {'x': 13, 'y': 4}}
#
# 09-30 09:49:45 - 0 -
# {'index': 0, 'num': 2, 'target': 2, 'targetTeam': 1, 'x': 15, 'y': 5}
#
# 09-30 09:49:48 - 3 -
# {'num': 1, 'sameTeam': False, 'target': 3}
#
# 09-30 09:49:51 - 0 -
# {'index': 0, 'num': 3, 'target': 3, 'targetTeam': 2, 'x': 12, 'y': 4}
#
# 09-30 09:49:58 - 3 -
# {'num': 1, 'sameTeam': False, 'target': 3}
#
# 09-30 09:50:02 - 3 -
# {'num': 2, 'sameTeam': False, 'target': 1}
#
# 09-30 09:50:06 - 3 -
# {'num': 1, 'sameTeam': False, 'target': 1}
#
# 09-30 09:50:14 - 0 -
# {'index': 0, 'num': 3, 'target': 1, 'targetTeam': 2, 'x': 14, 'y': 4}
#
# 09-30 09:50:19 - 3 -
# {'num': 1, 'sameTeam': False, 'target': 1}
