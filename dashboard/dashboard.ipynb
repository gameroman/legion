# %%
# %load_ext autoreload
# %autoreload 2

import dashboard as db
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
db.plot_dau_and_new_players()

# %%
db.plot_games_per_mode()
# Out:
# {'DAU': [{'date': '2024-06-25', 'userCount': 1}, {'date': '2024-07-03', 'userCount': 1}, {'date': '2024-07-04', 'userCount': 2}], 'day1retention': {'returningPlayers': 1, 'retentionRate': 20}, 'day7retention': {'returningPlayers': 0, 'retentionRate': 0}, 'day30retention': {'returningPlayers': 0, 'retentionRate': 0}, 'yesterdayRetention': {'returningPlayers': 1, 'retentionRate': 20}, 'newPlayersPerDay': {'2024-07-03': 1}, 'gamesPerModePerDay': {'2024-07-04': {'0': 1, '1': 1}, '2024-07-03': {'0': 1}}, 'totalPlayers': 5, 'medianGameDuration': 0.5737333333333333}

# %%
db.display_retention_table()
db.print_additional_info()
# Out:
#   Retention Period  Returning Players  Retention Rate (%)
# 0            Day 1                  1                  20
# 1            Day 7                  0                   0
# 2           Day 30                  0                   0
# 3        Yesterday                  1                  20
# Median Game Duration: 0.57 min
# Total Players: 5
