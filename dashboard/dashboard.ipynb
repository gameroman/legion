# [{'date': '2024-09-19', 'newPlayers': 11}, {'date': '2024-09-20', 'newPlayers': 0}, {'date': '2024-09-21', 'newPlayers': 0}, {'date': '2024-09-22', 'newPlayers': 0}, {'date': '2024-09-23', 'newPlayers': 0}, {'date': '2024-09-24', 'newPlayers': 2}, {'date': '2024-09-25', 'newPlayers': 5}, {'date': '2024-09-26', 'newPlayers': 0}, {'date': '2024-09-27', 'newPlayers': 3}, {'date': '2024-09-28', 'newPlayers': 1}, {'date': '2024-09-29', 'newPlayers': 1}, {'date': '2024-09-30', 'newPlayers': 5}]

# %%
# db.plot_games_per_mode()

# %%
db.display_retention_table()
db.print_additional_info()
# Out:
#   Retention Period  Returning Players  Retention Rate (%)
# 0            Day 1                 10           10.101010
# 1            Day 7                  3            3.030303
# 2           Day 30                  0            0.000000
# 3        Yesterday                 10           10.101010
# Median Game Duration: 1.70 min
# Total Players: 99
# ATH of DAU: 19
# Yesterday's DAU: 1 (5.26% of ATH)

# %%
db.list_inactive_players()
# Out:
# Inactive Players (Total: 9):
# 905L8JTHgwQCZpH5t4fnqLbKhln1
# DSXDAyeFBAOrQqsD9XOHH7lLm463
# Nwuc3PggbyZyNs6oAvqZfjMoLGa2
# PLCs7l0UbfXz87HE3Z9oxKJcD7s1
# fEQAl28DQSZXCggptFVk5JqBeCu2
# gsCfm7MPWIdawSpnobovx182t3P2
# oEm9o8fwPIcHRTtm6FgqjmLGhPQ2
# wfjWXaQtCMPaUQ6mD3SsM3EJR013
# wkslrFeeJXRqUEfhlw19rbBsJlG2

# %%
db.get_player_log('6I0Fox5wVWdx5Uy94cyeQzSmdss1')
# Out:
# 09-15 12:38:48 - gameStart -
# {'gameId': 'fcd4278c-c7e3-438d-a649-0754350c64d0', 'league': None, 'mode': 0}
#
# 09-15 13:01:40 - gameStart -
# {'gameId': '94865105-46bd-4e72-9155-45680a6cecc9', 'league': None, 'mode': 0}
#
# 09-15 13:03:06 - reward -
# {'chests': [], 'elo': 0, 'gold': 9, 'key': None, 'xp': 0}
#
# 09-15 13:03:07 - gameComplete -
# {   'gameId': '94865105-46bd-4e72-9155-45680a6cecc9',
#     'league': None,
#     'mode': 0,
#     'results': {'audience': 20, 'score': 0.5625},
#     'winner': False}
#
# 09-18 10:46:45 - gameStart -
# {'gameId': 'c9e48296-4dae-4edc-a44f-851ba5c8c12c', 'league': None, 'mode': 0}
#
# 09-18 10:46:49 - gameStart -
# {'gameId': '1831fd83-3384-4dd5-8aca-e2085de6637d', 'league': None, 'mode': 0}
#
# 09-18 10:47:49 - joinQueue -
# '1'
#
# 09-18 10:47:56 - leaveQueue -
# None
#
# 09-18 10:56:11 - inventoryTransaction -
# {   'action': 0,
#     'characterId': 'jS8xC3S9yiBY19JG5SDI',
#     'index': 2,
#     'inventoryType': 'consumables'}
#
# 09-18 10:56:12 - inventoryTransaction -
# {   'action': 0,
#     'characterId': 'k39Pzgs9FQhdRBUO5aUv',
#     'index': 0,
#     'inventoryType': 'consumables'}
#
# 09-18 10:56:14 - inventoryTransaction -
# {   'action': 0,
#     'characterId': 'l4NyMi1N74FS1Z0XAN2X',
#     'index': 0,
#     'inventoryType': 'consumables'}
#
# 09-18 10:56:16 - gameStart -
# {'gameId': 'cd1b8e1a-96bc-483c-a599-1969f4b1206b', 'league': None, 'mode': 0}
#
# 09-18 10:57:35 - reward -
# {'chests': [], 'elo': 0, 'gold': 9, 'key': None, 'xp': 78}
#
# 09-18 10:57:36 - gameComplete -
# {   'gameId': 'cd1b8e1a-96bc-483c-a599-1969f4b1206b',
#     'league': None,
#     'mode': 0,
#     'results': {'audience': 1277.5, 'score': 0.5652244917468613},
#     'winner': True}
#
# 09-18 10:58:04 - purchaseItem -
# {'inventoryType': 2, 'itemId': 10, 'nb': 1, 'totalPrice': 500}
#
# 09-18 10:58:07 - purchaseItem -
# {'inventoryType': 2, 'itemId': 6, 'nb': 1, 'totalPrice': 500}
#
# 09-18 10:58:26 - inventoryTransaction -
# {   'action': 0,
#     'characterId': 'jS8xC3S9yiBY19JG5SDI',
#     'index': 0,
#     'inventoryType': 'spells'}
#
# 09-18 10:59:57 - gameStart -
# {'gameId': 'f02229b0-628b-484a-9336-0d532dcaa216', 'league': None, 'mode': 0}
#
# 09-18 11:02:59 - reward -
# {'chests': [], 'elo': 0, 'gold': 7, 'key': None, 'xp': 62}
#
# 09-18 11:02:59 - gameComplete -
# {   'gameId': 'f02229b0-628b-484a-9336-0d532dcaa216',
#     'league': None,
#     'mode': 0,
#     'results': {'audience': 525, 'score': 0.40262311956188623},
#     'winner': True}
#
# 09-18 11:03:45 - spendSP -
# {'amount': 3, 'characterId': 'jS8xC3S9yiBY19JG5SDI', 'stat': 'mp'}
#
# 09-18 12:34:58 - gameStart -
# {'gameId': 'e4f9a110-c496-4049-a34f-2979bd0c1062', 'league': None, 'mode': 0}
#
# 09-18 13:40:36 - gameStart -
# {'gameId': '4c1e85fb-8ce7-43bf-8bd2-f315ce50ef9b', 'league': None, 'mode': 0}
#
# 09-18 13:47:04 - gameStart -
# {'gameId': '3d26b775-2f28-4a4e-b6bd-2d5472131400', 'league': None, 'mode': 0}
#
# 09-18 14:45:33 - joinQueue -
# '1'
#
# 09-18 14:48:47 - gameStart -
# {'gameId': '4efccbb0-6ebf-469e-b48a-79f359cb91fb', 'league': 0, 'mode': '1'}
#
# 09-18 14:53:50 - reward -
# {   'chests': [   {   'color': 'bronze',
#                       'content': [   {   'amount': 1,
#                                          'frame': 4,
#                                          'id': 3,
#                                          'name': 'Hi-Ether',
#                                          'rarity': '0',
#                                          'type': 'consumable'}]}],
#     'elo': 0,
#     'gold': 62,
#     'key': 'bronze',
#     'xp': 98}
#
# 09-18 14:53:51 - gameComplete -
# {   'gameId': '4efccbb0-6ebf-469e-b48a-79f359cb91fb',
#     'league': 0,
#     'mode': '1',
#     'results': {'audience': 730, 'score': 0.32884976865240023},
#     'winner': True}
#
# 09-18 14:54:06 - joinQueue -
# '1'
#
# 09-18 14:54:09 - gameStart -
# {'gameId': '3dc7603c-12ff-4717-97e1-b0d5903afad7', 'league': 0, 'mode': '1'}
#
# 09-18 15:01:07 - reward -
# {'chests': [], 'elo': 0, 'gold': 72, 'key': 'silver', 'xp': 181}
#
# 09-18 15:01:11 - gameComplete -
# {   'gameId': '3dc7603c-12ff-4717-97e1-b0d5903afad7',
#     'league': 0,
#     'mode': '1',
#     'results': {'audience': 350, 'score': 0.43622799614178925},
#     'winner': True}
#
# 09-18 15:01:35 - joinQueue -
# '1'
#
# 09-18 15:01:37 - gameStart -
# {'gameId': 'f4114fb2-dd51-4396-9a8d-29853de8101d', 'league': 0, 'mode': '1'}
#
# 09-18 15:05:46 - reward -
# {   'chests': [   {   'color': 'bronze',
#                       'content': [   {   'amount': 1,
#                                          'frame': 12,
#                                          'id': 12,
#                                          'name': 'Bocca',
#                                          'rarity': '0',
#                                          'type': 'consumable'}]}],
#     'elo': 0,
#     'gold': 84,
#     'key': 'gold',
#     'xp': 343}
#
# 09-18 15:05:46 - gameComplete -
# {   'gameId': 'f4114fb2-dd51-4396-9a8d-29853de8101d',
#     'league': 0,
#     'mode': '1',
#     'results': {'audience': 620, 'score': 0.5592185592185592},
#     'winner': True}
#
# 09-18 15:07:05 - spendSP -
# {'amount': 6, 'characterId': 'k39Pzgs9FQhdRBUO5aUv', 'stat': 'hp'}
#
# 09-18 15:08:01 - joinQueue -
# '1'
#
# 09-18 15:08:04 - gameStart -
# {'gameId': '7e66be27-fc4c-4baa-9873-94fed7c050e8', 'league': 0, 'mode': '1'}
#
# 09-18 15:12:09 - reward -
# {   'chests': [   {   'color': 'bronze',
#                       'content': [   {   'amount': 1,
#                                          'frame': 5,
#                                          'id': 5,
#                                          'name': 'X-Ether',
#                                          'rarity': '0',
#                                          'type': 'consumable'}]}],
#     'elo': 0,
#     'gold': 74,
#     'key': None,
#     'xp': 313}
#
# 09-18 15:12:09 - gameComplete -
# {   'gameId': '7e66be27-fc4c-4baa-9873-94fed7c050e8',
#     'league': 0,
#     'mode': '1',
#     'results': {'audience': 735, 'score': 0.45890941150396336},
#     'winner': True}
#
# 09-18 15:14:29 - claimChest -
# {'chestType': 'bronze'}
#
# 09-18 15:14:33 - claimChest -
# {'chestType': 'silver'}
#
# 09-18 15:14:37 - claimChest -
# {'chestType': 'gold'}
#
# 09-18 15:15:33 - spendSP -
# {'amount': 7, 'characterId': 'l4NyMi1N74FS1Z0XAN2X', 'stat': 'mp'}
#
# 09-18 15:15:35 - inventoryTransaction -
# {   'action': 1,
#     'characterId': 'l4NyMi1N74FS1Z0XAN2X',
#     'index': 0,
#     'inventoryType': 'consumables'}
#
# 09-18 15:15:41 - spendSP -
# {'amount': 2, 'characterId': 'l4NyMi1N74FS1Z0XAN2X', 'stat': 'hp'}
#
# 09-18 15:15:49 - spendSP -
# {'amount': 3, 'characterId': 'jS8xC3S9yiBY19JG5SDI', 'stat': 'mp'}
#
# 09-18 15:16:07 - spendSP -
# {'amount': 3, 'characterId': 'jS8xC3S9yiBY19JG5SDI', 'stat': 'hp'}
#
# 09-18 15:17:09 - inventoryTransaction -
# {   'action': 0,
#     'characterId': 'l4NyMi1N74FS1Z0XAN2X',
#     'index': 6,
#     'inventoryType': 'consumables'}
#
# 09-18 15:17:18 - inventoryTransaction -
# {   'action': 0,
#     'characterId': 'jS8xC3S9yiBY19JG5SDI',
#     'index': 1,
#     'inventoryType': 'consumables'}
#
# 09-18 15:17:30 - inventoryTransaction -
# {   'action': 0,
#     'characterId': 'k39Pzgs9FQhdRBUO5aUv',
#     'index': 0,
#     'inventoryType': 'consumables'}
#
# 09-18 15:17:39 - inventoryTransaction -
# {   'action': 0,
#     'characterId': 'jS8xC3S9yiBY19JG5SDI',
#     'index': 1,
#     'inventoryType': 'consumables'}
#
# 09-18 15:17:43 - inventoryTransaction -
# {   'action': 0,
#     'characterId': 'jS8xC3S9yiBY19JG5SDI',
#     'index': 0,
#     'inventoryType': 'consumables'}
#
# 09-18 15:19:36 - joinQueue -
# '1'
#
# 09-18 15:21:09 - joinQueue -
# '1'
#
# 09-18 15:21:10 - leaveQueue -
# None
#
# 09-18 15:22:24 - gameStart -
# {'gameId': '3731d155-2d23-4a15-b35d-d80393a55968', 'league': 0, 'mode': '1'}
#
# 09-18 15:24:49 - reward -
# {   'chests': [   {   'color': 'bronze',
#                       'content': [   {   'amount': 1,
#                                          'frame': 12,
#                                          'id': 12,
#                                          'name': 'Bocca',
#                                          'rarity': '0',
#                                          'type': 'consumable'}]},
#                   {   'color': 'bronze',
#                       'content': [   {   'amount': 1,
#                                          'frame': 4,
#                                          'id': 3,
#                                          'name': 'Hi-Ether',
#                                          'rarity': '0',
#                                          'type': 'consumable'}]}],
#     'elo': 0,
#     'gold': 79,
#     'key': None,
#     'xp': 381}
#
# 09-18 15:24:49 - gameComplete -
# {   'gameId': '3731d155-2d23-4a15-b35d-d80393a55968',
#     'league': 0,
#     'mode': '1',
#     'results': {'audience': 1465, 'score': 0.5295295257179928},
#     'winner': True}
#
# 09-18 15:29:15 - spendSP -
# {'amount': 3, 'characterId': 'k39Pzgs9FQhdRBUO5aUv', 'stat': 'hp'}
#
# 09-18 15:29:23 - spendSP -
# {'amount': 1, 'characterId': 'l4NyMi1N74FS1Z0XAN2X', 'stat': 'hp'}
#
# 09-18 15:29:26 - spendSP -
# {'amount': 2, 'characterId': 'l4NyMi1N74FS1Z0XAN2X', 'stat': 'mp'}
#
# 09-18 15:29:33 - spendSP -
# {'amount': 1, 'characterId': 'jS8xC3S9yiBY19JG5SDI', 'stat': 'hp'}
#
# 09-18 15:29:35 - spendSP -
# {'amount': 2, 'characterId': 'jS8xC3S9yiBY19JG5SDI', 'stat': 'mp'}
#
# 09-18 15:31:27 - purchaseItem -
# {'inventoryType': 1, 'itemId': 10, 'nb': 1, 'totalPrice': 1000}
#
# 09-18 15:31:32 - inventoryTransaction -
# {   'action': 0,
#     'characterId': 'k39Pzgs9FQhdRBUO5aUv',
#     'index': 0,
#     'inventoryType': 'equipment'}
#
# 09-18 20:06:55 - gameStart -
# {'gameId': '051c2d19-fc57-4a98-9667-ebfeda3c9bd8', 'league': None, 'mode': 0}
#
# 09-18 20:07:10 - gameStart -
# {'gameId': 'da8668f3-a002-403c-a95a-a1f9b315cbb6', 'league': None, 'mode': 0}
#
# 09-19 10:01:16 - gameStart -
# {'gameId': 'a516e473-e74b-4221-a77b-72ff1bb6dd9c', 'league': None, 'mode': 0}
#
# 09-19 10:03:08 - joinQueue -
# '1'
#
# 09-19 10:03:09 - leaveQueue -
# None
#
# 09-19 10:03:20 - joinQueue -
# '1'
#
# 09-19 10:04:00 - gameStart -
# {'gameId': 'c20fd100-89be-4573-af7e-d011b6b2f94a', 'league': 0, 'mode': '1'}
#
# 09-19 10:05:08 - reward -
# {   'chests': [   {   'color': 'bronze',
#                       'content': [   {   'amount': 1,
#                                          'frame': 0,
#                                          'id': 0,
#                                          'name': 'Potion',
#                                          'rarity': '0',
#                                          'type': 'consumable'}]}],
#     'elo': 0,
#     'gold': 99,
#     'key': 'bronze',
#     'xp': 185}
#
# 09-19 10:05:08 - gameComplete -
# {   'gameId': 'c20fd100-89be-4573-af7e-d011b6b2f94a',
#     'league': 0,
#     'mode': '1',
#     'results': {'audience': 720, 'score': 0.6527777777777778},
#     'winner': True}
#
# 09-19 15:16:26 - claimChest -
# {'chestType': 'bronze'}
#
# 09-19 15:17:12 - joinQueue -
# '1'
#
# 09-19 15:20:58 - gameStart -
# {'gameId': 'fb536f48-5ccc-4f19-a025-9e4c144c38c3', 'league': 0, 'mode': '1'}
#
# 09-19 15:35:00 - joinQueue -
# '1'
#
# 09-19 15:35:03 - gameStart -
# {'gameId': '2f0432f1-3dda-4962-8f96-cffa63d4d376', 'league': 1, 'mode': '1'}
#
# 09-19 15:35:18 - joinQueue -
# '1'
#
# 09-19 15:35:23 - gameStart -
# {'gameId': 'e00853be-512c-40ca-b212-b8e5fcb33d14', 'league': 0, 'mode': '1'}
#
# 09-19 15:35:28 - reward -
# {'chests': [], 'elo': 0, 'gold': None, 'key': 'silver', 'xp': 0}
#
# 09-19 15:35:28 - gameComplete -
# {   'gameId': 'e00853be-512c-40ca-b212-b8e5fcb33d14',
#     'league': 0,
#     'mode': '1',
#     'results': {'audience': 0, 'score': None},
#     'winner': False}
#
# 09-19 15:37:04 - joinQueue -
# '1'
#
# 09-19 15:37:11 - gameStart -
# {'gameId': '7b1dd213-a332-44c0-ab80-0df1ce542835', 'league': 0, 'mode': '1'}
#
# 09-19 15:37:14 - reward -
# {'chests': [], 'elo': 0, 'gold': None, 'key': 'gold', 'xp': 0}
#
# 09-19 15:37:15 - gameComplete -
# {   'gameId': '7b1dd213-a332-44c0-ab80-0df1ce542835',
#     'league': 0,
#     'mode': '1',
#     'results': {'audience': 0, 'score': None},
#     'winner': False}
#
# 09-19 15:38:58 - joinQueue -
# '1'
#
# 09-19 15:39:05 - leaveQueue -
# None
#
# 09-19 15:39:38 - gameStart -
# {'gameId': 'd05167d5-2983-4365-a8b8-17ccf463e985', 'league': None, 'mode': 0}
#
# 09-19 16:05:25 - joinQueue -
# '1'
#
# 09-19 16:05:26 - leaveQueue -
# None
#
# 09-19 16:05:32 - joinQueue -
# '1'
#
# 09-19 16:05:37 - gameStart -
# {'gameId': 'd812bbd1-70f5-4e4a-9ada-115764c5ff10', 'league': 0, 'mode': '1'}
#
# 09-19 16:06:05 - joinQueue -
# '1'
#
# 09-19 16:06:09 - gameStart -
# {'gameId': 'cec34da9-e2b8-44c7-a3cb-97f243b3ed12', 'league': 0, 'mode': '1'}
#
# 09-19 16:06:26 - joinQueue -
# '1'
#
# 09-19 16:06:29 - gameStart -
# {'gameId': '56300da8-00dd-4698-b65e-22adba3fc090', 'league': 0, 'mode': '1'}
#
#
# Player Summary:
# Join Date: September 14, 2024 at 20:00:33
# Last Active Date: September 30, 2024 at 10:45:40
# Gold: 501
# Rank: 1
# All Time Rank: 1
# Losses Streak: 0
#
# Characters:
#   Character ID: k39Pzgs9FQhdRBUO5aUv
#     Level: 5
#     XP: 236
#     SP: 3
#     All Time SP: 12
#     Skills: []
#     Inventory: []
#     Equipment: {'weapon': -1, 'armor': -1, 'gloves': -1, 'belt': -1, 'helmet': -1, 'boots': -1, 'right_ring': -1, 'necklace': 10, 'left_ring': -1}
#
#   Character ID: l4NyMi1N74FS1Z0XAN2X
#     Level: 6
#     XP: 109
#     SP: 3
#     All Time SP: 15
#     Skills: [9]
#     Inventory: []
#     Equipment: {'weapon': -1, 'armor': -1, 'gloves': -1, 'belt': -1, 'helmet': -1, 'boots': -1, 'right_ring': -1, 'necklace': -1, 'left_ring': -1}
#
#   Character ID: jS8xC3S9yiBY19JG5SDI
#     Level: 6
#     XP: 265
#     SP: 3
#     All Time SP: 15
#     Skills: [0, 6]
#     Inventory: [3]
#     Equipment: {'weapon': -1, 'armor': 7, 'gloves': -1, 'belt': -1, 'helmet': -1, 'boots': -1, 'right_ring': -1, 'necklace': -1, 'left_ring': -1}
#
#
# Utilization Stats: {'everEquippedConsumable': False, 'everEquippedSpell': False, 'everEquippedEquipment': False, 'everPlayedRanked': False, 'everUsedSpell': False, 'everPlayedPractice': True, 'everUsedSpells': True, 'everPurchased': True, 'everSpentSP': True, 'everPlayedCasual': True, 'everOpenedDailyLoot': True}
#
# Games Played:
# Game ID: fcd4278c-c7e3-438d-a649-0754350c64d0
#
# Game ID: 94865105-46bd-4e72-9155-45680a6cecc9
#
# Game ID: c9e48296-4dae-4edc-a44f-851ba5c8c12c
#
# Game ID: 1831fd83-3384-4dd5-8aca-e2085de6637d
#
# Game ID: cd1b8e1a-96bc-483c-a599-1969f4b1206b
#
# Game ID: f02229b0-628b-484a-9336-0d532dcaa216
#
# Game ID: e4f9a110-c496-4049-a34f-2979bd0c1062
#
# Game ID: 4c1e85fb-8ce7-43bf-8bd2-f315ce50ef9b
#
# Game ID: 3d26b775-2f28-4a4e-b6bd-2d5472131400
#
# Game ID: 4efccbb0-6ebf-469e-b48a-79f359cb91fb
#
# Game ID: 3dc7603c-12ff-4717-97e1-b0d5903afad7
#
# Game ID: f4114fb2-dd51-4396-9a8d-29853de8101d
#
# Game ID: 7e66be27-fc4c-4baa-9873-94fed7c050e8
#
# Game ID: 3731d155-2d23-4a15-b35d-d80393a55968
#
# Game ID: 051c2d19-fc57-4a98-9667-ebfeda3c9bd8
#
# Game ID: da8668f3-a002-403c-a95a-a1f9b315cbb6
#
# Game ID: a516e473-e74b-4221-a77b-72ff1bb6dd9c
#
# Game ID: c20fd100-89be-4573-af7e-d011b6b2f94a
#
# Game ID: fb536f48-5ccc-4f19-a025-9e4c144c38c3
#
# Game ID: 2f0432f1-3dda-4962-8f96-cffa63d4d376
#
# Game ID: e00853be-512c-40ca-b212-b8e5fcb33d14
#
# Game ID: 7b1dd213-a332-44c0-ab80-0df1ce542835
#
# Game ID: d05167d5-2983-4365-a8b8-17ccf463e985
#
# Game ID: d812bbd1-70f5-4e4a-9ada-115764c5ff10
#
# Game ID: cec34da9-e2b8-44c7-a3cb-97f243b3ed12
#
# Game ID: 56300da8-00dd-4698-b65e-22adba3fc090

# %%
# db.get_game_log('145c6a50-101d-48e0-a72a-209bcbde688b')
