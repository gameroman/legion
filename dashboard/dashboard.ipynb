# %%
# %load_ext autoreload
# %autoreload 2

import dashboard as db

# %%
db.plot_dau_and_new_players()
# Out:
# Making API call
# {'DAU': [{'date': '2024-08-21', 'userCount': 1}, {'date': '2024-08-22', 'userCount': 2}, {'date': '2024-08-23', 'userCount': 1}, {'date': '2024-08-24', 'userCount': 1}, {'date': '2024-08-25', 'userCount': 1}, {'date': '2024-08-26', 'userCount': 3}, {'date': '2024-08-27', 'userCount': 1}, {'date': '2024-08-28', 'userCount': 1}, {'date': '2024-08-29', 'userCount': 1}, {'date': '2024-08-30', 'userCount': 1}, {'date': '2024-08-31', 'userCount': 2}, {'date': '2024-09-02', 'userCount': 2}, {'date': '2024-09-03', 'userCount': 1}, {'date': '2024-09-04', 'userCount': 1}, {'date': '2024-09-05', 'userCount': 1}, {'date': '2024-09-06', 'userCount': 1}, {'date': '2024-09-07', 'userCount': 2}, {'date': '2024-09-08', 'userCount': 1}, {'date': '2024-09-09', 'userCount': 1}, {'date': '2024-09-10', 'userCount': 1}, {'date': '2024-09-11', 'userCount': 12}, {'date': '2024-09-13', 'userCount': 7}, {'date': '2024-09-14', 'userCount': 3}, {'date': '2024-09-15', 'userCount': 4}, {'date': '2024-09-16', 'userCount': 19}, {'date': '2024-09-18', 'userCount': 2}, {'date': '2024-09-19', 'userCount': 8}, {'date': '2024-09-20', 'userCount': 2}, {'date': '2024-09-22', 'userCount': 1}, {'date': '2024-09-24', 'userCount': 2}, {'date': '2024-09-25', 'userCount': 3}, {'date': '2024-09-27', 'userCount': 3}, {'date': '2024-09-28', 'userCount': 1}, {'date': '2024-09-29', 'userCount': 1}, {'date': '2024-09-30', 'userCount': 8}, {'date': '2024-10-01', 'userCount': 3}], 'day1retention': {'returningPlayers': 10, 'retentionRate': 10}, 'day7retention': {'returningPlayers': 4, 'retentionRate': 4}, 'day30retention': {'returningPlayers': 0, 'retentionRate': 0}, 'yesterdayRetention': {'returningPlayers': 10, 'retentionRate': 10}, 'newPlayersPerDay': {'2024-09-19': 11, '2024-09-11': 16, '2024-09-16': 32, '2024-09-27': 3, '2024-09-30': 6, '2024-09-02': 1, '2024-09-14': 3, '2024-09-15': 6, '2024-08-26': 2, '2024-09-18': 1, '2024-09-28': 1, '2024-09-13': 6, '2024-09-25': 5, '2024-09-07': 2, '2024-09-03': 1, '2024-09-24': 2, '2024-08-22': 1, '2024-09-29': 1}, 'gamesPerModePerDay': {'2024-09-18': {'0': 10, '1': 5}, '2024-09-09': {'0': 22}, '2024-09-06': {'0': 10}, '2024-09-19': {'0': 7, '1': 14}, '2024-09-22': {'0': 1}, '2024-09-30': {'0': 6, '1': 3}, '2024-09-14': {'0': 4}, '2024-10-01': {'0': 2, '1': 1}, '2024-09-07': {'0': 9}, '2024-08-28': {'0': 3}, '2024-09-20': {'
# In: {'2024-09-19': 11, '2024-09-11': 16, '2024-09-16': 32, '2024-09-27': 3, '2024-09-30': 6, '2024-09-02': 1, '2024-09-14': 3, '2024-09-15': 6, '2024-08-26': 2, '2024-09-18': 1, '2024-09-28': 1, '2024-09-13': 6, '2024-09-25': 5, '2024-09-07': 2, '2024-09-03': 1, '2024-09-24': 2, '2024-08-22': 1, '2024-09-29': 1}
# Out: [{'date': '2024-09-19', 'newPlayers': 11}, {'date': '2024-09-20', 'newPlayers': 0}, {'date': '2024-09-21', 'newPlayers': 0}, {'date': '2024-09-22', 'newPlayers': 0}, {'date': '2024-09-23', 'newPlayers': 0}, {'date': '2024-09-24', 'newPlayers': 2}, {'date': '2024-09-25', 'newPlayers': 5}, {'date': '2024-09-26', 'newPlayers': 0}, {'date': '2024-09-27', 'newPlayers': 3}, {'date': '2024-09-28', 'newPlayers': 1}, {'date': '2024-09-29', 'newPlayers': 1}, {'date': '2024-09-30', 'newPlayers': 6}, {'date': '2024-10-01', 'newPlayers': 0}]
# [{'date': '2024-09-19', 'newPlayers': 11}, {'date': '2024-09-20', 'newPlayers': 0}, {'date': '2024-09-21', 'newPlayers': 0}, {'date': '2024-09-22', 'newPlayers': 0}, {'date': '2024-09-23', 'newPlayers': 0}, {'date': '2024-09-24', 'newPlayers': 2}, {'date': '2024-09-25', 'newPlayers': 5}, {'date': '2024-09-26', 'newPlayers': 0}, {'date': '2024-09-27', 'newPlayers': 3}, {'date': '2024-09-28', 'newPlayers': 1}, {'date': '2024-09-29', 'newPlayers': 1}, {'date': '2024-09-30', 'newPlayers': 6}, {'date': '2024-10-01', 'newPlayers': 0}]

# %%
# db.plot_games_per_mode()

# %%
db.display_retention_table()
db.print_additional_info()
# Out:
#   Retention Period  Returning Players  Retention Rate (%)
# 0            Day 1                 10                  10
# 1            Day 7                  4                   4
# 2           Day 30                  0                   0
# 3        Yesterday                 10                  10
# Median Game Duration: 1.70 min
# Total Players: 100
# ATH of DAU: 19
# Yesterday's DAU: 8 (42.11% of ATH)

# %%
db.list_inactive_players()
# Out:
# Inactive Players (Total: 8):
# 905L8JTHgwQCZpH5t4fnqLbKhln1
# DSXDAyeFBAOrQqsD9XOHH7lLm463
# PLCs7l0UbfXz87HE3Z9oxKJcD7s1
# fEQAl28DQSZXCggptFVk5JqBeCu2
# gsCfm7MPWIdawSpnobovx182t3P2
# oEm9o8fwPIcHRTtm6FgqjmLGhPQ2
# wfjWXaQtCMPaUQ6mD3SsM3EJR013
# wkslrFeeJXRqUEfhlw19rbBsJlG2

# %%
db.get_player_log('5Vgs2JdhilOL28dQ031Y4K7npef2')
# Out:
# 09-30 12:31:16 - joinQueue -
# '1'
#
# 09-30 12:31:39 - leaveQueue -
# None
#
# 09-30 12:31:39 - gameStart -
# {'gameId': 'eb21a748-cd02-465d-895d-9b2dde391868', 'league': 0, 'mode': '1'}
#
# 09-30 12:31:39 - gameStart -
# {'gameId': 'a2f4d26d-bc43-4257-8fe3-f037da664ed5', 'league': 0, 'mode': '1'}
#
# 09-30 12:31:39 - gameStart -
# {'gameId': '161382c4-f847-4d4d-ad17-02143ece36d5', 'league': 0, 'mode': '1'}
#
# 09-30 12:33:52 - reward -
# {'chests': [], 'elo': 0, 'gold': 86, 'key': None, 'xp': 744}
#
# 09-30 12:33:52 - gameComplete -
# {   'gameId': 'eb21a748-cd02-465d-895d-9b2dde391868',
#     'league': 0,
#     'mode': '1',
#     'results': {'audience': 40, 'score': 0.55625},
#     'winner': False}
#
# 09-30 12:35:31 - leaveQueue -
# None
#
# 09-30 12:35:31 - gameStart -
# {'gameId': 'ded8ba5b-c99b-43c9-80e8-aa6e0e9db228', 'league': None, 'mode': 0}
#
#
# Player Summary:
# Join Date: September 30, 2024 at 10:13:52
# Last Active Date: September 30, 2024 at 10:35:37
# Gold: 1087
# Rank: 1
# All Time Rank: 1
# Losses Streak: 0
#
# Characters:
#   Character ID: HcW6Z7y1j0b7pAL6wF6w
#     Level: 1
#     XP: 0
#     SP: 0
#     All Time SP: 0
#     Skills: []
#     Inventory: []
#     Equipment: {'weapon': -1, 'armor': -1, 'gloves': -1, 'belt': -1, 'helmet': -1, 'boots': -1, 'right_ring': -1, 'necklace': -1, 'left_ring': -1}
#
#   Character ID: IQP97K8cmt7jDNpcKrj7
#     Level: 5
#     XP: 244
#     SP: 12
#     All Time SP: 12
#     Skills: [9]
#     Inventory: []
#     Equipment: {'weapon': -1, 'armor': -1, 'gloves': -1, 'belt': -1, 'helmet': -1, 'boots': -1, 'right_ring': -1, 'necklace': -1, 'left_ring': -1}
#
#   Character ID: BFXNbtlKWcXuKcCVz3yu
#     Level: 1
#     XP: 0
#     SP: 0
#     All Time SP: 0
#     Skills: [0]
#     Inventory: []
#     Equipment: {'weapon': -1, 'armor': -1, 'gloves': -1, 'belt': -1, 'helmet': -1, 'boots': -1, 'right_ring': -1, 'necklace': -1, 'left_ring': -1}
#
#
# Utilization Stats: {'everEquippedConsumable': False, 'everEquippedSpell': False, 'everPurchased': False, 'everEquippedEquipment': False, 'everSpentSP': False, 'everOpenedDailyLoot': False, 'everPlayedRanked': False, 'everUsedSpell': False, 'everPlayedPractice': False, 'everPlayedCasual': True}
#
# Games Played:
# Game ID: eb21a748-cd02-465d-895d-9b2dde391868
#
# Game ID: a2f4d26d-bc43-4257-8fe3-f037da664ed5
#
# Game ID: 161382c4-f847-4d4d-ad17-02143ece36d5
#
# Game ID: ded8ba5b-c99b-43c9-80e8-aa6e0e9db228

# %%
# db.get_game_log('145c6a50-101d-48e0-a72a-209bcbde688b')
