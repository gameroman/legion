# %%
# %load_ext autoreload
# %autoreload 2

import dashboard as db
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
db.plot_dau_and_new_players()
# Out:
# [{'date': '2024-07-07', 'userCount': 1}, {'date': '2024-07-08', 'userCount': 2}, {'date': '2024-07-09', 'userCount': 0}, {'date': '2024-07-10', 'userCount': 0}, {'date': '2024-07-11', 'userCount': 0}, {'date': '2024-07-12', 'userCount': 1}, {'date': '2024-07-13', 'userCount': 0}, {'date': '2024-07-14', 'userCount': 0}, {'date': '2024-07-15', 'userCount': 0}, {'date': '2024-07-16', 'userCount': 0}, {'date': '2024-07-17', 'userCount': 0}, {'date': '2024-07-18', 'userCount': 0}, {'date': '2024-07-19', 'userCount': 0}, {'date': '2024-07-20', 'userCount': 0}, {'date': '2024-07-21', 'userCount': 0}, {'date': '2024-07-22', 'userCount': 0}, {'date': '2024-07-23', 'userCount': 0}, {'date': '2024-07-24', 'userCount': 0}, {'date': '2024-07-25', 'userCount': 0}, {'date': '2024-07-26', 'userCount': 0}, {'date': '2024-07-27', 'userCount': 0}, {'date': '2024-07-28', 'userCount': 0}, {'date': '2024-07-29', 'userCount': 0}, {'date': '2024-07-30', 'userCount': 2}, {'date': '2024-07-31', 'userCount': 1}, {'date': '2024-08-01', 'userCount': 2}, {'date': '2024-08-02', 'userCount': 3}, {'date': '2024-08-03', 'userCount': 1}, {'date': '2024-08-04', 'userCount': 1}, {'date': '2024-08-05', 'userCount': 4}, {'date': '2024-08-06', 'userCount': 5}]
# In: {'2024-08-06': 5, '2024-08-02': 2, '2024-07-08': 1, '2024-08-05': 3, '2024-07-07': 1}
# Out: [{'date': '2024-08-06', 'newPlayers': 5}]
# [{'date': '2024-08-06', 'newPlayers': 5}]

# %%
db.plot_games_per_mode()

# %%
db.display_retention_table()
db.print_additional_info()
# Out:
#   Retention Period  Returning Players  Retention Rate (%)
# 0            Day 1                  4           33.333333
# 1            Day 7                  2           16.666667
# 2           Day 30                  0            0.000000
# 3        Yesterday                  4           33.333333
# Median Game Duration: 0.94 min
# Total Players: 12
# ATH of DAU: 5
# Yesterday's DAU: 4 (80.00% of ATH)

# %%
db.list_inactive_players()
# Out:
# Inactive Players (Total: 2):
# Leg9CC3eRvkHVVFICnR6UlgeDJLR
# d5bSxLY9VQAMnbgNCWOlMSB0eOpQ

# %%
# db.get_player_log('tWRb1g7aSEGRWdJpDugYD4b0D1Y4')

# %%
# db.get_game_log('0e762e3f-e156-4caa-8e45-2d7ef62e84e5')
