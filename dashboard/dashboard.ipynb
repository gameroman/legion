# %%
# %load_ext autoreload
# %autoreload 2

import dashboard as db

# %%
db.plot_dau_and_new_players()
# Out:
# [{'date': '2024-06-25', 'userCount': 1}, {'date': '2024-06-26', 'userCount': 0}, {'date': '2024-06-27', 'userCount': 0}, {'date': '2024-06-28', 'userCount': 0}, {'date': '2024-06-29', 'userCount': 0}, {'date': '2024-06-30', 'userCount': 0}, {'date': '2024-07-01', 'userCount': 0}, {'date': '2024-07-02', 'userCount': 0}, {'date': '2024-07-03', 'userCount': 1}, {'date': '2024-07-04', 'userCount': 2}, {'date': '2024-07-05', 'userCount': 1}, {'date': '2024-07-06', 'userCount': 1}]

# %%
db.plot_games_per_mode()

# %%
db.display_retention_table()
db.print_additional_info()
# Out:
#   Retention Period  Returning Players  Retention Rate (%)
# 0            Day 1                  1                  20
# 1            Day 7                  0                   0
# 2           Day 30                  0                   0
# 3        Yesterday                  1                  20
# Median Game Duration: 0.68 min
# Total Players: 5
# ATH of DAU: 2
# Yesterday's DAU: 1 (50.00% of ATH)

# %%
db.get_action_log('2YC61HEm5XoA1cUxMxqwM81mhxUX')
# Out:
# 07-04 10:52:15 - reward -
# {'chests': [], 'elo': 0, 'gold': 9, 'key': None, 'xp': 14}
#
# 07-04 10:58:14 - reward -
# {   'chests': [   {   'color': 'bronze',
#                       'content': [   {   'amount': 1,
#                                          'id': 7,
#                                          'name': 'X-Elixir',
#                                          'rarity': '1',
#                                          'type': 'consumable'},
#                                      {   'amount': 1,
#                                          'id': 1,
#                                          'name': 'Ether',
#                                          'rarity': '0',
#                                          'type': 'consumable'}]}],
#     'elo': 0,
#     'gold': 96,
#     'key': 'bronze',
#     'xp': 150}
#
# 07-04 10:58:14 - gameComplete -
# {   'gameId': '9b716f65-08a2-48fc-9a36-87595beced77',
#     'league': 0,
#     'mode': '1',
#     'results': {'audience': 580, 'score': 0.6875},
#     'winner': True}
#
# 07-05 16:34:42 - claimChest -
# {'chestType': 'bronze'}
#
# 07-05 16:34:58 - inventoryTransaction -
# {   'action': 0,
#     'characterId': 'VGJXNvl1ZqmIHIDhy1xv',
#     'index': 11,
#     'inventoryType': 'consumables'}
#
# 07-05 16:34:59 - inventoryTransaction -
# {   'action': 0,
#     'characterId': 'VGJXNvl1ZqmIHIDhy1xv',
#     'index': 10,
#     'inventoryType': 'consumables'}
#
# 07-05 16:35:06 - inventoryTransaction -
# {   'action': 0,
#     'characterId': 'clbMypp30xeGmOSc8zZi',
#     'index': 1,
#     'inventoryType': 'spells'}
#
# 07-05 16:35:08 - inventoryTransaction -
# {   'action': 0,
#     'characterId': 'clbMypp30xeGmOSc8zZi',
#     'index': 1,
#     'inventoryType': 'spells'}
#
# 07-05 16:35:13 - inventoryTransaction -
# {   'action': 0,
#     'characterId': 'xmrK7PP5bpcqVu1rfUKg',
#     'index': 0,
#     'inventoryType': 'spells'}
#
# 07-05 16:35:20 - inventoryTransaction -
# {   'action': 0,
#     'characterId': 'clbMypp30xeGmOSc8zZi',
#     'index': 2,
#     'inventoryType': 'equipment'}
#
# 07-05 16:35:23 - inventoryTransaction -
# {   'action': 0,
#     'characterId': 'clbMypp30xeGmOSc8zZi',
#     'index': 1,
#     'inventoryType': 'equipment'}
#
# 07-05 16:36:23 - purchaseCharacter -
# {'characterId': '6HNiTY3oR9t2ME56at6P', 'price': 13125}
#
# 07-05 16:36:25 - fetchLeaderboard -
# {'tabId': 0}
#
# 07-05 16:36:56 - purchaseItem -
# {'inventoryType': 1, 'itemId': 4, 'nb': 1, 'totalPrice': 7000}
#
# 07-05 16:39:24 - joinQueue -
# '1'
#
# 07-05 16:39:25 - gameStart -
# {'gameId': 'c6a1e864-63f2-4984-9647-5a17a1ac6bed', 'league': 0, 'mode': '1'}
#
# 07-05 16:39:25 - gameStart -
# {'gameId': 'c6a1e864-63f2-4984-9647-5a17a1ac6bed', 'league': 0, 'mode': '1'}
#
# 07-05 16:40:03 - joinQueue -
# '1'
#
# 07-05 16:42:34 - joinQueue -
# '1'
#
# 07-05 16:42:35 - gameStart -
# {'gameId': 'f332d155-ed0e-4b2c-b451-9ed48291275c', 'league': 0, 'mode': '1'}
#
# 07-05 16:42:35 - gameStart -
# {'gameId': 'f332d155-ed0e-4b2c-b451-9ed48291275c', 'league': 0, 'mode': '1'}
#
# 07-05 16:43:17 - joinQueue -
# '1'
#
# 07-05 16:44:36 - joinQueue -
# '1'
#
# 07-05 16:45:42 - joinQueue -
# '1'
#
# 07-05 16:45:52 - leaveQueue -
# None
#
# 07-05 16:48:27 - joinQueue -
# '1'
#
# 07-05 16:48:32 - leaveQueue -
# None
#
# 07-05 16:52:39 - joinQueue -
# '1'
#
# 07-05 16:52:59 - joinQueue -
# '1'
#
# 07-05 16:53:00 - gameStart -
# {'gameId': 'cdbd6612-c07f-4f9e-a513-6375b9d53a32', 'league': 0, 'mode': '1'}
#
# 07-05 16:53:00 - gameStart -
# {'gameId': 'cdbd6612-c07f-4f9e-a513-6375b9d53a32', 'league': 0, 'mode': '1'}
#
# 07-05 16:54:32 - joinQueue -
# '1'
#
# 07-05 16:54:36 - joinQueue -
# '1'
#
# 07-05 16:54:53 - leaveQueue -
# None
#
# 07-05 16:54:58 - leaveQueue -
# None
#
# 07-05 17:11:44 - reward -
# {'chests': [], 'elo': 0, 'gold': 9, 'key': None, 'xp': 19}
#
# 07-05 17:14:29 - joinQueue -
# '1'
#
# 07-05 17:14:33 - leaveQueue -
# None
#
# 07-05 17:14:35 - gameStart -
# {'gameId': '18d595f6-47b2-4ecb-8088-e38061a469fe', 'league': None, 'mode': 0}
#
# 07-05 17:15:06 - reward -
# {'chests': [], 'elo': 0, 'gold': 7, 'key': None, 'xp': 19}
#
# 07-05 17:15:06 - gameComplete -
# {   'gameId': '18d595f6-47b2-4ecb-8088-e38061a469fe',
#     'league': None,
#     'mode': 0,
#     'results': {'audience': 1131, 'score': 0.4375},
#     'winner': True}
#
# 07-05 17:18:51 - gameStart -
# {'gameId': '1b63ac3a-dd23-432c-93f3-02260eb3a2f4', 'league': None, 'mode': 0}
#
# 07-05 17:25:47 - gameStart -
# {'gameId': '0e762e3f-e156-4caa-8e45-2d7ef62e84e5', 'league': None, 'mode': 0}
#
# 07-05 17:26:28 - reward -
# {'chests': [], 'elo': 0, 'gold': 10, 'key': None, 'xp': 24}
#
# 07-05 17:26:28 - gameComplete -
# {   'gameId': '0e762e3f-e156-4caa-8e45-2d7ef62e84e5',
#     'league': None,
#     'mode': 0,
#     'results': {'audience': 881, 'score': 0.6875},
#     'winner': True}

# %%
db.get_game_log('0e762e3f-e156-4caa-8e45-2d7ef62e84e5')
# Out:
# 07-05 17:25:56 - 2 -
# {'num': 1, 'tile': {'x': 12, 'y': 3}}
#
# 07-05 17:26:14 - 0 -
# {'index': 2, 'num': 3, 'x': 3, 'y': 3}
#
# 07-05 17:26:16 - 0 -
# {'index': 1, 'num': 2, 'target': 2, 'targetTeam': 2, 'x': 4, 'y': 5}
#
# 07-05 17:26:18 - 2 -
# {'num': 1, 'tile': {'x': 10, 'y': 5}}
#
# 07-05 17:26:22 - 2 -
# {'num': 1, 'tile': {'x': 7, 'y': 5}}
#
# 07-05 17:26:23 - 2 -
# {'num': 1, 'tile': {'x': 5, 'y': 5}}
#
# 07-05 17:26:24 - 3 -
# {'num': 1, 'target': 2}
#
# 07-05 17:26:25 - 3 -
# {'num': 1, 'target': 2}
#
# 07-05 17:26:26 - 3 -
# {'num': 1, 'target': 2}
