# %%
# %load_ext autoreload
# %autoreload 2

import dashboard as db

# %%
db.plot_dau_and_new_players()
# Out:
# Making API call
# {'DAU': [{'date': '2024-07-07', 'userCount': 1}, {'date': '2024-07-08', 'userCount': 2}, {'date': '2024-07-12', 'userCount': 1}, {'date': '2024-07-30', 'userCount': 2}, {'date': '2024-07-31', 'userCount': 1}, {'date': '2024-08-01', 'userCount': 2}, {'date': '2024-08-02', 'userCount': 3}, {'date': '2024-08-03', 'userCount': 1}, {'date': '2024-08-04', 'userCount': 1}, {'date': '2024-08-05', 'userCount': 4}], 'day1retention': {'returningPlayers': 3, 'retentionRate': 42.857142857142854}, 'day7retention': {'returningPlayers': 2, 'retentionRate': 28.57142857142857}, 'day30retention': {'returningPlayers': 0, 'retentionRate': 0}, 'yesterdayRetention': {'returningPlayers': 3, 'retentionRate': 42.857142857142854}, 'newPlayersPerDay': {'2024-08-02': 2, '2024-07-08': 1, '2024-08-05': 3, '2024-07-07': 1}, 'gamesPerModePerDay': {'2024-07-31': {'0': 21}, '2024-07-27': {'0': 1}, '2024-08-03': {'0': 12}, '2024-08-01': {'0': 13, '1': 6}, '2024-08-05': {'0': 6}, '2024-07-30': {'0': 2, '1': 1}, '2024-07-10': {'0': 2, '1': 1}, '2024-07-26': {'0': 6}, '2024-07-18': {'0': 12, '1': 2, '2': 1}, '2024-08-04': {'0': 3}, '2024-07-22': {'0': 1}, '2024-07-23': {'0': 4}, '2024-08-02': {'0': 1}, '2024-07-08': {'2': 1}}, 'totalPlayers': 7, 'medianGameDuration': 0.9426, 'inactivePlayerIds': ['Leg9CC3eRvkHVVFICnR6UlgeDJLR', 'd5bSxLY9VQAMnbgNCWOlMSB0eOpQ']}
# [{'date': '2024-07-07', 'userCount': 1}, {'date': '2024-07-08', 'userCount': 2}, {'date': '2024-07-09', 'userCount': 0}, {'date': '2024-07-10', 'userCount': 0}, {'date': '2024-07-11', 'userCount': 0}, {'date': '2024-07-12', 'userCount': 1}, {'date': '2024-07-13', 'userCount': 0}, {'date': '2024-07-14', 'userCount': 0}, {'date': '2024-07-15', 'userCount': 0}, {'date': '2024-07-16', 'userCount': 0}, {'date': '2024-07-17', 'userCount': 0}, {'date': '2024-07-18', 'userCount': 0}, {'date': '2024-07-19', 'userCount': 0}, {'date': '2024-07-20', 'userCount': 0}, {'date': '2024-07-21', 'userCount': 0}, {'date': '2024-07-22', 'userCount': 0}, {'date': '2024-07-23', 'userCount': 0}, {'date': '2024-07-24', 'userCount': 0}, {'date': '2024-07-25', 'userCount': 0}, {'date': '2024-07-26', 'userCount': 0}, {'date': '2024-07-27', 'userCount': 0}, {'date': '2024-07-28', 'userCount': 0}, {'date': '2024-07-29', 'userCount': 0}, {'date': '2024-07-30', 'userCount': 2}, {'date': '2024-07-31', 'userCount': 1}, {'date': '2024-08-01', 'userCount': 2}, {'date': '2024-08-02', 'userCount': 3}, {'date': '2024-08-03', 'userCount': 1}, {'date': '2024-08-04', 'userCount': 1}, {'date': '2024-08-05', 'userCount': 4}]
# In: {'2024-08-02': 2, '2024-07-08': 1, '2024-08-05': 3, '2024-07-07': 1}
# Out: [{'date': '2024-08-02', 'newPlayers': 2}, {'date': '2024-08-03', 'newPlayers': 0}, {'date': '2024-08-04', 'newPlayers': 0}, {'date': '2024-08-05', 'newPlayers': 3}]
# [{'date': '2024-08-02', 'newPlayers': 2}, {'date': '2024-08-03', 'newPlayers': 0}, {'date': '2024-08-04', 'newPlayers': 0}, {'date': '2024-08-05', 'newPlayers': 3}]

# %%
db.plot_games_per_mode()

# %%
db.display_retention_table()
db.print_additional_info()
# Out:
#   Retention Period  Returning Players  Retention Rate (%)
# 0            Day 1                  3           42.857143
# 1            Day 7                  2           28.571429
# 2           Day 30                  0            0.000000
# 3        Yesterday                  3           42.857143
# Median Game Duration: 0.94 min
# Total Players: 7
# ATH of DAU: 4
# Yesterday's DAU: 1 (25.00% of ATH)

# %%
db.list_inactive_players()
# Out:
# Inactive Players (Total: 2):
# Leg9CC3eRvkHVVFICnR6UlgeDJLR
# d5bSxLY9VQAMnbgNCWOlMSB0eOpQ

# %%
db.get_player_log('tWRb1g7aSEGRWdJpDugYD4b0D1Y4')
# Out:
# 08-05 11:53:08 - gameStart -
# {'gameId': '0d20e145-3b39-43a8-9257-18d79640a1bf', 'league': None, 'mode': 0}
#
# 08-05 11:53:56 - reward -
# {'chests': [], 'elo': 0, 'gold': 10, 'key': None, 'xp': 15}
#
# 08-05 11:53:56 - gameComplete -
# {   'gameId': '0d20e145-3b39-43a8-9257-18d79640a1bf',
#     'league': None,
#     'mode': 0,
#     'results': {'audience': 310, 'score': 0.6875},
#     'winner': True}
#
# 08-05 11:55:26 - purchaseItem -
# {'inventoryType': 0, 'itemId': 0, 'nb': 1, 'totalPrice': 100}
#
# 08-05 11:55:59 - gameStart -
# {'gameId': '6ebdb95f-b386-461c-9bc3-84c6287da9d0', 'league': None, 'mode': 0}
#
# 08-05 11:56:53 - gameStart -
# {'gameId': '6b158d1e-e587-4ee8-833f-fda960894b75', 'league': None, 'mode': 0}
#
# 08-05 11:59:37 - gameStart -
# {'gameId': 'c80e432d-584a-4de2-8d81-83dc33f1adeb', 'league': None, 'mode': 0}
#
# 08-05 11:59:55 - gameStart -
# {'gameId': 'faf133d7-5c6f-470e-a779-7460424e52e2', 'league': None, 'mode': 0}
#
# 08-05 20:42:37 - fetchLeaderboard -
# {'tabId': 0}
#
#
# Player Summary:
# Gold: 240
# Rank: 2
# All Time Rank: 2
# Losses streak: 0
#
# Characters:
#   Character ID: G9TGC3ubsaM7nKOjMhtD
#     Level: 1
#     XP: 15
#     SP: 0
#     All Time SP: 0
#     Skills: []
#     Inventory: []
#     Equipment: {'weapon': -1, 'armor': -1, 'helmet': -1, 'belt': -1, 'gloves': -1, 'boots': -1, 'left_ring': -1, 'right_ring': -1, 'necklace': -1}
#
#   Character ID: ZHbQVOHG1vfCK5dSmab9
#     Level: 1
#     XP: 0
#     SP: 0
#     All Time SP: 0
#     Skills: [9]
#     Inventory: []
#     Equipment: {'weapon': -1, 'armor': -1, 'helmet': -1, 'belt': -1, 'gloves': -1, 'boots': -1, 'left_ring': -1, 'right_ring': -1, 'necklace': -1}
#
#   Character ID: 2a2DV2I96ctv2MjggeFk
#     Level: 1
#     XP: 0
#     SP: 0
#     All Time SP: 0
#     Skills: [0]
#     Inventory: []
#     Equipment: {'weapon': -1, 'armor': -1, 'helmet': -1, 'belt': -1, 'gloves': -1, 'boots': -1, 'left_ring': -1, 'right_ring': -1, 'necklace': -1}
#
#
# Utilization Stats: {'everSpentSP': False, 'everOpenedDailyLoot': False, 'everEquippedConsumable': False, 'everEquippedEquipment': False, 'everEquippedSpell': False, 'everUsedSpell': False, 'everPlayedCasual': False, 'everPlayedRanked': False, 'everPlayedPractice': True, 'everPurchased': True}

# %%
# db.get_game_log('0e762e3f-e156-4caa-8e45-2d7ef62e84e5')
